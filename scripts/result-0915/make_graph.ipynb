# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
xlabels = ["1", "2", "4", "8"]
stamp = ["SIFT1M", "GIST1M", "SIFT10M", "DEEP10M"]
index_stamp = ["IVF_Flat", "HNSW"]


create_time_sift1m_ivfflat = [3.07, 2.2, 1.75, 1.44]
create_time_sift1m_hnswlib = [89, 47.1, 25.9, 17.64]
search_time_sift1m_ivfflat = [3.07, 2.2, 1.75, 1.44]
search_time_sift1m_hnswlib = [89, 47.1, 25.9, 17.64]

create_time_gist1m_ivfflat = [17.03, 10.4, 6.59, 4.98]
create_time_gist1m_hnswlib = [455, 238.7, 124.9, 73.13]
search_time_gist1m_ivfflat = [19.86, 10.89, 7.5, 4.24]
search_time_gist1m_hnswlib = [1.57, 1.21, 0.69, 0.375]

create_time_sift10m_ivfflat = [83, 55.62, 43.04, 35.55]
create_time_sift10m_hnswlib = [1563, 846.4, 447.68, 303.75]
search_time_sift10m_ivfflat = [31.68, 17.5, 11.29, 6.29]
search_time_sift10m_hnswlib = [6.28, 3.18, 1.98, 1.4]

create_time_deep10m_ivfflat = [70.5, 49.04, 40.89, 33.94]
create_time_deep10m_hnswlib = [1291, 682, 352.75, 251.68]
search_time_deep10m_ivfflat = [25.61, 13.89, 9.5, 4.93]
search_time_deep10m_hnswlib = [5.3, 2.57, 2.14, 1.27]

# %%
def make_graph(title,label,data):
  plt.plot(xlabels,data,marker='o',label=label)
  plt.legend()
  plt.xlabel("threads")
  plt.ylabel("time(seconds)")
  plt.title(title)
  plt.savefig(title+".png")

make_graph("create_index_"+"SIFT1M"+"_"+"IVF_Flat","SIFT1M",create_time_sift1m_ivfflat)
